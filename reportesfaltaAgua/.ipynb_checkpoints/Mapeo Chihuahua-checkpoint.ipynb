# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 9]

# %%
df_falta_agua = pd.read_csv('falta-agua-jun2018-jun2019.csv')
df_fuga_agua = pd.read_csv('fugas-de-agua-jun8-al-jun19.csv')
# Out:
# C:\Users\alanr\anaconda3\envs\JMAS\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
# valid_cols = ['no. Folio', 'usuario', 'fecha', 'tipo de problema', 'zona', 'colonia', 'solucion/respuesta', 'status folio']
same_cols = set(df_falta_agua.columns) & set(df_fuga_agua.columns)

same_cols
# Out:
# {'atendio trabajo',
#  'calle',
#  'colonia',
#  'contrato',
#  'departamento',
#  'departamento.1',
#  'diametro',
#  'direccion',
#  'direccion.1',
#  'entre calle',
#  'fecha',
#  'fecha captura',
#  'fecha fin',
#  'fecha inicio',
#  'fecha transmitido',
#  'material toma',
#  'no. Folio',
#  'numero',
#  'observaciones',
#  'operador recibe llamada',
#  'problema',
#  'reporta problema',
#  'responsable zona',
#  'responsable zona.1',
#  'saldo',
#  'solucion/respuesta',
#  'status folio',
#  'telefono',
#  'tiene tinaco',
#  'tipo de problema',
#  'usuario',
#  'zona',
#  'zona.1'}

# %%
valid_cols = ['usuario','fecha','zona', 'calle', 'colonia', 'numero']
df_falta_agua = df_falta_agua[valid_cols]
df_fuga_agua = df_fuga_agua[valid_cols]

# %%
df_fuga_agua.describe()
# Out:
#         usuario            fecha         zona  calle                colonia  \
# count     18506            18628        18628  18626                  18626
# unique    13880            17817           10   4609                    786
# top     ANONIMO  12/17/2018 8:56  F MED NORTE     3A  RIBERAS DE SACRAMENTO
# freq        130                3         4858     69                    972
#
#        numero
# count   14292
# unique   5458
# top      2007
# freq       25

# %%
df_falta_agua.fecha = pd.to_datetime(df_falta_agua.fecha)
df_falta_agua = df_falta_agua.set_index('fecha')
df_falta_agua = df_falta_agua.loc[df_falta_agua.index.dropna()]
df_falta_agua['Year'] = df_falta_agua.index.year
df_falta_agua['Month'] = df_falta_agua.index.month
df_falta_agua['Week'] = df_falta_agua.index.isocalendar().week
df_falta_agua['Weekday Name'] = df_falta_agua.index.weekday
df_falta_agua['Date'] = df_falta_agua.index.date
df_falta_agua['Time'] = [float('{0}.{1}'.format(el.time().hour, el.time().minute)) for el in df_falta_agua.index]

# %%
df_fuga_agua.fecha = pd.to_datetime(df_fuga_agua.fecha)
df_fuga_agua = df_fuga_agua.set_index('fecha')
df_fuga_agua = df_fuga_agua.loc[df_fuga_agua.index.dropna()]
df_fuga_agua['Year'] = df_fuga_agua.index.year
df_fuga_agua['Month'] = df_fuga_agua.index.month
df_fuga_agua['Week'] = df_fuga_agua.index.isocalendar().week
df_fuga_agua['Weekday Name'] = df_fuga_agua.index.weekday
df_fuga_agua['Date'] = df_fuga_agua.index.date
df_fuga_agua['Time'] = [float('{0}.{1}'.format(el.time().hour, el.time().minute)) for el in df_fuga_agua.index]

# %%
def get_zone_pos(str_zone):
    for num in range(7):
        if str(num + 1) in str_zone:
            return num
    return -1

# %%
df_falta_agua = df_falta_agua[~df_falta_agua.index.duplicated(keep='first')]
df_fuga_agua = df_falta_agua[~df_falta_agua.index.duplicated(keep='first')]

# %%
df_fuga_agua['Zona'] = [get_zone_pos(str_zone) for str_zone in df_fuga_agua.zona]

# %%
df_falta_agua['Zona'] = [get_zone_pos(str_zone) for str_zone in df_falta_agua.zona]

# %%
df_falta_agua.describe()
# Out:
#                Year         Month          Week  Weekday Name          Time  \
# count  16662.000000  16662.000000  16662.000000  16662.000000  16662.000000
# mean    2018.526888      5.576461     22.260593      2.685932     12.012580
# std        0.499292      2.867731     12.325168      1.945501      4.684982
# min     2018.000000      1.000000      1.000000      0.000000      0.180000
# 25%     2018.000000      3.000000     13.000000      1.000000      7.590000
# 50%     2019.000000      6.000000     22.000000      3.000000     10.590000
# 75%     2019.000000      7.000000     28.000000      4.000000     17.100000
# max     2019.000000     12.000000     52.000000      6.000000     23.800000
#
#                Zona
# count  16662.000000
# mean       3.218581
# std        1.413575
# min       -1.000000
# 25%        2.000000
# 50%        4.000000
# 75%        4.000000
# max        5.000000

# %%
df_fuga_agua.describe()
# Out:
#                Year         Month          Week  Weekday Name          Time  \
# count  16662.000000  16662.000000  16662.000000  16662.000000  16662.000000
# mean    2018.526888      5.576461     22.260593      2.685932     12.012580
# std        0.499292      2.867731     12.325168      1.945501      4.684982
# min     2018.000000      1.000000      1.000000      0.000000      0.180000
# 25%     2018.000000      3.000000     13.000000      1.000000      7.590000
# 50%     2019.000000      6.000000     22.000000      3.000000     10.590000
# 75%     2019.000000      7.000000     28.000000      4.000000     17.100000
# max     2019.000000     12.000000     52.000000      6.000000     23.800000
#
#                Zona
# count  16662.000000
# mean       3.218581
# std        1.413575
# min       -1.000000
# 25%        2.000000
# 50%        4.000000
# 75%        4.000000
# max        5.000000

# %%
def getData(From, To, Offset, df_in):
        df = df_in.copy()
        df = df[df.index >= From]
        df = df[df.index <= To]
        hist = []
        
        walker = From
        i = 0
        while(walker< To):
            df_temp = df.copy()
            df_temp = df_temp[df_temp.index >= walker]
            df_temp = df_temp[df_temp.index < walker + Offset]
            zone_list = [len(df_temp[df_temp.Zona == i].index) for i in range(0,6)]
            hist.append([walker, len(df_temp.index), zone_list])
            i += 1
            walker += Offset
        return hist

# %%
df_falta_agua.head()
# Out:
#                                                    usuario    zona  \
# fecha
# 2018-06-01 04:43:00  MARIA DE LOURDES  PIÑON DE CISNEROS    Zona 3
# 2018-06-01 04:53:00       VELIA GUADALUPE  VALENCIA TORRES  Zona 5
# 2018-06-01 05:14:00                   MA LUISA  PAREDES  G  Zona 5
# 2018-06-01 05:18:00                         LUIS J  ARZOLA  Zona 3
# 2018-06-01 05:22:00                    RAUL  LUJAN HOLGUIN  Zona 5
#
#                                   calle             colonia numero  Year  \
# fecha
# 2018-06-01 04:43:00  PV GONZALEZ COSSIO             GRANJAS   4905  2018
# 2018-06-01 04:53:00          SISOGUICHI              MARMOL   8621  2018
# 2018-06-01 05:14:00        DIEGO LUCERO  DIVISION DEL NORTE    504  2018
# 2018-06-01 05:18:00      GARCIA SALINAS             GRANJAS   6101  2018
# 2018-06-01 05:22:00    REYNA D J ESPAÑA              MARMOL   3037  2018
#
#                      Month  Week  Weekday Name        Date  Time  Zona
# fecha
# ...

# %%
df_falta_agua.tail()
# Out:
#                                            usuario    zona           calle  \
# fecha
# 2019-06-19 10:43:00   MARIA TERESA MONTAÑO SANCHEZ  Zona 4  RIO PAPALOAPAN
# 2019-06-19 10:46:00     MARIA TOMASA TARANGO DURAN  Zona 5         OJINAGA
# 2019-06-19 10:53:00  MARIA VELIA GONZALEZ IRACHETA  Zona 6         59 1/2A
# 2019-06-19 11:12:00  VICTOR MANUEL VENZOR RENTERIA  Zona 5             21A
# 2019-06-19 11:13:00   TANIA LETICIA VILLAGRAN KONG  Zona 6        CALLE 53
#
#                             colonia numero  Year  Month  Week  Weekday Name  \
# fecha
# 2019-06-19 10:43:00  ALFREDO CHAVEZ   8601  2019      6    25             2
# 2019-06-19 10:46:00    VILLA JUAREZ    506  2019      6    25             2
# 2019-06-19 10:53:00         POPULAR   1400  2019      6    25             2
# 2019-06-19 11:12:00    VILLA JUAREZ    302  2019      6    25             2
# 2019-06-19 11:13:00     ARQUITECTOS    808  2019      6    25             2
#
# ...

# %%
df_fuga_agua.head()
# Out:
#                                                    usuario    zona  \
# fecha
# 2018-06-01 04:43:00  MARIA DE LOURDES  PIÑON DE CISNEROS    Zona 3
# 2018-06-01 04:53:00       VELIA GUADALUPE  VALENCIA TORRES  Zona 5
# 2018-06-01 05:14:00                   MA LUISA  PAREDES  G  Zona 5
# 2018-06-01 05:18:00                         LUIS J  ARZOLA  Zona 3
# 2018-06-01 05:22:00                    RAUL  LUJAN HOLGUIN  Zona 5
#
#                                   calle             colonia numero  Year  \
# fecha
# 2018-06-01 04:43:00  PV GONZALEZ COSSIO             GRANJAS   4905  2018
# 2018-06-01 04:53:00          SISOGUICHI              MARMOL   8621  2018
# 2018-06-01 05:14:00        DIEGO LUCERO  DIVISION DEL NORTE    504  2018
# 2018-06-01 05:18:00      GARCIA SALINAS             GRANJAS   6101  2018
# 2018-06-01 05:22:00    REYNA D J ESPAÑA              MARMOL   3037  2018
#
#                      Month  Week  Weekday Name        Date  Time  Zona
# fecha
# ...

# %%
df_fuga_agua.tail()
# Out:
#                                            usuario    zona           calle  \
# fecha
# 2019-06-19 10:43:00   MARIA TERESA MONTAÑO SANCHEZ  Zona 4  RIO PAPALOAPAN
# 2019-06-19 10:46:00     MARIA TOMASA TARANGO DURAN  Zona 5         OJINAGA
# 2019-06-19 10:53:00  MARIA VELIA GONZALEZ IRACHETA  Zona 6         59 1/2A
# 2019-06-19 11:12:00  VICTOR MANUEL VENZOR RENTERIA  Zona 5             21A
# 2019-06-19 11:13:00   TANIA LETICIA VILLAGRAN KONG  Zona 6        CALLE 53
#
#                             colonia numero  Year  Month  Week  Weekday Name  \
# fecha
# 2019-06-19 10:43:00  ALFREDO CHAVEZ   8601  2019      6    25             2
# 2019-06-19 10:46:00    VILLA JUAREZ    506  2019      6    25             2
# 2019-06-19 10:53:00         POPULAR   1400  2019      6    25             2
# 2019-06-19 11:12:00    VILLA JUAREZ    302  2019      6    25             2
# 2019-06-19 11:13:00     ARQUITECTOS    808  2019      6    25             2
#
# ...

# %%
From = pd.Timestamp('2018-06-01')
To = pd.Timestamp('2019-06-01')

hist = getData(From,To,pd.DateOffset(weeks=2),df_falta_agua)
# hist

# %%
x = [reg[0] for reg in hist]
y = [reg[1] for reg in hist]

plt.plot(x,y)
plt.title('Histograma reportes')
plt.xlabel('Fecha de registro')
plt.ylabel('Cantidad de registros')
_ = plt.xticks(x,[time.date() for time in x], rotation=30)

# %%
x = [reg[0] for reg in hist]
y = [reg[2] for reg in hist]

z = 2
plt.plot(x,[zone[z] for zone in y], label=f'Zona {z}')

plt.title(f'Histograma reportes zona {z}')
plt.xlabel('Fecha de registro')
plt.ylabel('Cantidad de registros')
_ = plt.xticks(x,[time.date() for time in x], rotation=30)

# %%
x = [reg[0] for reg in hist]
y = [reg[2] for reg in hist]

for z in range(0,6):
    plt.plot(x,[zone[z] for zone in y], label=f'Zona {z}')

plt.legend()
plt.title('Histograma reportes por zona')
plt.xlabel('Fecha de registro')
plt.ylabel('Cantidad de registros')
_ = plt.xticks(x,[time.date() for time in x], rotation=30)

# %%
import gmaps
import gmaps.datasets
import googlemaps
API_KEY = "AIzaSyCt_wpPg7VrDr02EL88Twxik6midOK3WnY"
gmaps.configure(api_key=API_KEY)
mapsClient = googlemaps.Client(API_KEY)

# %%
ChihuahuaMapsData = mapsClient.geocode('Chihuahua, Chihuahua, Mx')

# %%
ChihuahuaCoords = ChihuahuaMapsData[0]['geometry']['location']
ChihuahuaCoords = (ChihuahuaCoords['lat'],ChihuahuaCoords['lng'])
ChihuahuaCoords
# Out:
# (28.6329957, -106.0691004)

# %%
# gmaps.figure(center=ChihuahuaCoords, zoom_level=11)

# %%
# Chihuahua = gmaps.figure(center=ChihuahuaArcGIS, zoom_level=11)

# %%
# Casa = geolocator.geocode('Aquiles, Serdan, 2337, Chihuahua, Chihuahua, Mx')[1][:2]
# markers = gmaps.marker_layer([Casa])
# Chihuahua.add_layer(markers)
# Chihuahua

# %%
ChihuahuaStr = 'Chihuahua, Chihuahua, Mx'
queryZona = [None]*6
for zona in range(6):
    df_zona = df_falta_agua[df_falta_agua.Zona == zona]
#     df_zona = df_zona.head(20)
    df_zona = df_zona.sample(n=20)
    queryZona[zona] = [str(df_zona.loc[i]['numero']) +', '+ df_zona.loc[i]['calle'] +', '+ df_zona.loc[i]['colonia'] +', '+ ChihuahuaStr for i in df_zona.index]

# %%
queryZona[1]
# Out:
# ['290, CUAUHTEMOC, REVOLUCION, Chihuahua, Chihuahua, Mx',
#  '9708, CORDILLERA ALAI, CORDILLERAS, Chihuahua, Chihuahua, Mx',
#  '2289, COLEGIO SANTA MONICA, MISION UNIVERSIDAD, Chihuahua, Chihuahua, Mx',
#  '2461, COLEGIO SAN ADRIAN, PASEO DE LAS MISIONES, Chihuahua, Chihuahua, Mx',
#  '4713, PV POTRERO DEL LLANO, LOS POTREROS, Chihuahua, Chihuahua, Mx',
#  '4904, MONTE BELLO, QUINTAS CAROLINAS, Chihuahua, Chihuahua, Mx',
#  '365, AVELINA GALLEGOS, VILLA, Chihuahua, Chihuahua, Mx',
#  '32, GENARO \xa0VAZQUEZ, TIERRA Y LIBERTAD, Chihuahua, Chihuahua, Mx',
#  '290, CD JULIMES, REVOLUCION, Chihuahua, Chihuahua, Mx',
#  '318, HOCHIMIN, IGNACIO RODRIGUEZ, Chihuahua, Chihuahua, Mx',
#  '12101, VIALIDAD SACRAMENTO, REAL DE POTREROS PLAZA, Chihuahua, Chihuahua, Mx',
#  '4212, UNIV DE BRESCIA, LOMAS UNIVERSIDAD, Chihuahua, Chihuahua, Mx',
#  '3009, NIÑOS HEROES, FELIPE ANGELES, Chihuahua, Chihuahua, Mx',
#  '226, IGNACIO RODRIGUEZ, REVOLUCION, Chihuahua, Chihuahua, Mx',
# ...

# %%
#Google maps
mapsResponse = [[mapsClient.geocode(query) for query in queryZona[i]] for i in range(6)]
zonaCoord = [[(mapsResponse[j][i][0]['geometry']['location']['lat'],mapsResponse[j][i][0]['geometry']['location']['lng']) for i in range(20)] for j in range(6)]
zonaCoord
# Out:
# [[(28.6898863, -106.1165624),
#   (28.742202, -106.1165201),
#   (28.7397937, -106.1647254),
#   (28.7508229, -106.1469919),
#   (28.7267174, -106.1037882),
#   (28.7368107, -106.1224474),
#   (28.7244622, -106.1515859),
#   (28.7428635, -106.1143181),
#   (28.7129322, -106.1514775),
#   (28.749695, -106.1242668),
#   (28.7691913, -106.1685293),
#   (28.7355954, -106.1031235),
#   (28.7115426, -106.152944),
#   (28.7234637, -106.1169894),
#   (28.7240373, -106.1535995),
#   (28.7736195, -106.1662697),
#   (28.7406481, -106.1176159),
#   (36.834047, -2.4637136),
#   (28.74039239999999, -106.1616209),
#   (28.7742639, -106.1661467)],
#  [(28.6990061, -106.1194185),
#   (28.7004815, -106.1481751),
#   (28.7053957, -106.1506226),
#   (28.7084347, -106.1541996),
#   (28.7086898, -106.0871268),
#   (28.7215439, -106.0908249),
#   (28.683644, -106.1077869),
#   (28.6834714, -106.11567),
#   (28.7069259, -106.1154237),
#   (28.6807254, -106.129497),
#   (28.71446599999999, -106.086732),
# ...

# %%
Chihuahua = gmaps.figure(center=ChihuahuaCoords, zoom_level=11)
markers = []
markers.append(gmaps.symbol_layer(zonaCoord[0], fill_color='green', stroke_color='green',scale=2))
markers.append(gmaps.symbol_layer(zonaCoord[1], fill_color='red', stroke_color='red',scale=2))
markers.append(gmaps.symbol_layer(zonaCoord[2], fill_color='blue', stroke_color='blue',scale=2))
markers.append(gmaps.symbol_layer(zonaCoord[3], fill_color='lime', stroke_color='lime',scale=2))
markers.append(gmaps.symbol_layer(zonaCoord[4], fill_color='purple', stroke_color='purple',scale=2))
markers.append(gmaps.symbol_layer(zonaCoord[5], fill_color='aqua', stroke_color='aqua',scale=2))

for i in range(6):
    Chihuahua.add_layer(markers[i])

Chihuahua
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
from geopy.geocoders import ArcGIS
geolocator = ArcGIS()
ChihuahuaCoords = geolocator.geocode('Chihuahua, Chihuahua, Mx')
ChihuahuaCoords = ChihuahuaCoords[1][:2]
ChihuahuaCoords
# Out:
# (28.635680000000036, -106.07591999999994)

# %%
zonaCoord = [[geolocator.geocode(query)[1][:2] for query in queryZona[i]] for i in range(6)]
zonaCoord[1]
# Out:
# [(28.70272100047859, -106.11055006378139),
#  (28.699814177492122, -106.14869183948282),
#  (28.70659425521358, -106.14863560784177),
#  (28.708430011155286, -106.15434002417807),
#  (28.708880035536772, -106.08785992306092),
#  (28.72146001491764, -106.0908399830064),
#  (28.683650004064503, -106.10777000249725),
#  (28.68480871347181, -106.11641326485615),
#  (28.706718989427397, -106.11593864167178),
#  (28.685421532571617, -106.1318372510168),
#  (28.70630431919278, -106.08137005978219),
#  (28.623033278174702, -106.04832079181757),
#  (28.60125000000005, -105.99658999999997),
#  (28.69846109553463, -106.10430996271539),
#  (28.623033278174702, -106.04832079181757),
#  (28.60125000000005, -105.99658999999997),
#  (28.722089998760296, -106.10124997147418),
#  (28.7063531581961, -106.09725403155848),
#  (28.698950262865885, -106.12709191623966),
#  (28.675308609812497, -106.14080600812466)]

# %%
ChihuahuaArcGis = gmaps.figure(center=ChihuahuaCoords, zoom_level=11)
markers = []
markers.append(gmaps.symbol_layer(zonaCoord[0], fill_color='green', stroke_color='green',scale=2))
markers.append(gmaps.symbol_layer(zonaCoord[1], fill_color='red', stroke_color='red',scale=2))
markers.append(gmaps.symbol_layer(zonaCoord[2], fill_color='blue', stroke_color='blue',scale=2))
markers.append(gmaps.symbol_layer(zonaCoord[3], fill_color='lime', stroke_color='lime',scale=2))
markers.append(gmaps.symbol_layer(zonaCoord[4], fill_color='purple', stroke_color='purple',scale=2))
markers.append(gmaps.symbol_layer(zonaCoord[5], fill_color='aqua', stroke_color='aqua',scale=2))

for i in range(6):
    ChihuahuaArcGis.add_layer(markers[i])

ChihuahuaArcGis
# Out:
# Figure(layout=FigureLayout(height='420px'))
